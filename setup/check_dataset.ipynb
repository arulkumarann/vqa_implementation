# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
vqa = np.load(r'vqa_implementation/datasets/train.npy', allow_pickle=True)

# %%
len(vqa)
# Out:
# 443757

# %%
idx = 0
vqa[idx].keys()
# Out:
# dict_keys(['image_name', 'image_path', 'question_id', 'question_str', 'question_tokens', 'all_answers', 'valid_answers'])

# %%
vqa[idx]
# Out:
# {'image_name': 'COCO_train2014_000000458752',
#  'image_path': '/teamspace/studios/this_studio/vqa_implementation/datasets/Resized_Images/train2014/COCO_train2014_000000458752.jpg',
#  'question_id': 458752000,
#  'question_str': 'What is this photo taken looking through?',
#  'question_tokens': ['what',
#   'is',
#   'this',
#   'photo',
#   'taken',
#   'looking',
#   'through',
#   '?'],
#  'all_answers': ['net',
#   'net',
#   'net',
#   'netting',
#   'net',
#   'net',
#   'mesh',
#   'net',
#   'net',
#   'net'],
#  'valid_answers': ['net', 'net', 'net', 'net', 'net', 'net', 'net', 'net']}

# %%
plt.figure()
image = Image.open(vqa[idx]['image_path'])
plt.imshow(image)
plt.show()

# %%
(vqa[idx]['all_answers'])
# Out:
# ['net', 'net', 'net', 'netting', 'net', 'net', 'mesh', 'net', 'net', 'net']

# %%
(vqa[idx]['valid_answers'])
# Out:
# ['net', 'net', 'net', 'net', 'net', 'net', 'net', 'net']

# %%
len(vqa[idx]['valid_answers'])
# Out:
# 8
